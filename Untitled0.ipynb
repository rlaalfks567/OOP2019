# %%
# !ls
# Out:
# adc.json  drive  sample_data

# %%
cd drive
# Out:
# /content/drive

# %%
# !ls
# Out:
#  멀티미디어  'Colab Notebooks'

# %%
cd work
# Out:
# /content/drive/멀티미디어/work

# %%
# !ls
# Out:
# data

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

#img = cv2.imread("./sample_data/messi.jpg")
img = cv2.imread("./data/sample02.jpg")
#plt.imshow(img)

img_cvt=cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img_cvt)
plt.show()
